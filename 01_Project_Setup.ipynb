# %% [markdown]
# <a href="https://colab.research.google.com/github/dev-gauravpingale/banking-data-platform-pyspark/blob/main/01_Project_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Banking Data Platform using PySpark

## Sprint 0 - Project Setup
##Author: Gaurav Pingale

##Objective:
##Set up the development environment for the Banking Data Platform project using Google Colab and PySpark.
